# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('payment_data.csv')
df.head()
# Out:
#          id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0  58987402       0       0       0        0           1         10
# 1  58995151       0       0       0        0           1          5
# 2  58997200       0       0       0        0           2          5
# 3  54988608       0       0       0        0           3         10
# 4  54987763       0       0       0        0           2         10
#
#    prod_limit update_date  new_balance  highest_balance report_date
# 0     16500.0  04/12/2016          0.0              NaN         NaN
# 1         NaN  04/12/2016     588720.0         491100.0         NaN
# 2         NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3     37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4         NaN  03/12/2016      15147.6              NaN  26/04/2016

# %% [markdown]
# PUT YOUR DESIRED DIRECTORY INSIDE : pd.read_csv("Your Directory")

# %%
df1=pd.read_csv('customer_data.csv')
df1.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2      0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3      1  58995168      7  1335.5      1  151000.0      2     11      5
# 4      0  54987320      7     NaN      2   59000.0      2     11      5
#
#    fea_8  fea_9  fea_10      fea_11
# 0    109      5  151300  244.948974
# 1    100      3  341759  207.173840
# 2    101      5   72001    1.000000
# 3    110      3   60084    1.000000
# 4    108      4  450081  197.403141

# %%
df2 = pd.merge(df1, df, on='id')
df2.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      1  54982665      5  1245.5      3   77000.0      2     15      5
# 2      1  54982665      5  1245.5      3   77000.0      2     15      5
# 3      1  54982665      5  1245.5      3   77000.0      2     15      5
# 4      0  59004779      4  1277.0      1  113000.0      2      8     -1
#
#    fea_8  ...  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  prod_limit  \
# 0    109  ...       0       0        0           9         10     60500.0
# 1    109  ...       0       0        0          18         10         NaN
# 2    109  ...       0       0        0           1          5         NaN
# 3    109  ...       2      26    11906           6         10         NaN
# 4    100  ...       0       0        0           4          6         NaN
#
#    update_date  new_balance  highest_balance  report_date
# ...

# %%
df2.isnull().sum()
# Out:
# label                 0
# id                    0
# fea_1                 0
# fea_2              1028
# fea_3                 0
# fea_4                 0
# fea_5                 0
# fea_6                 0
# fea_7                 0
# fea_8                 0
# fea_9                 0
# fea_10                0
# fea_11                0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# dtype: int64

# %%
df2=df2.drop(columns='update_date')
df2.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      1  54982665      5  1245.5      3   77000.0      2     15      5
# 2      1  54982665      5  1245.5      3   77000.0      2     15      5
# 3      1  54982665      5  1245.5      3   77000.0      2     15      5
# 4      0  59004779      4  1277.0      1  113000.0      2      8     -1
#
#    fea_8  ...  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0    109  ...       0       0       0        0           9         10
# 1    109  ...       0       0       0        0          18         10
# 2    109  ...       0       0       0        0           1          5
# 3    109  ...       0       2      26    11906           6         10
# 4    100  ...       0       0       0        0           4          6
#
#    prod_limit  new_balance  highest_balance  report_date
# ...

# %%
df2=df2.drop(columns='report_date')
df2.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      1  54982665      5  1245.5      3   77000.0      2     15      5
# 2      1  54982665      5  1245.5      3   77000.0      2     15      5
# 3      1  54982665      5  1245.5      3   77000.0      2     15      5
# 4      0  59004779      4  1277.0      1  113000.0      2      8     -1
#
#    fea_8  ...      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  \
# 0    109  ...  244.948974       0       0       0        0           9
# 1    109  ...  244.948974       0       0       0        0          18
# 2    109  ...  244.948974       0       0       0        0           1
# 3    109  ...  244.948974       0       2      26    11906           6
# 4    100  ...  207.173840       0       0       0        0           4
#
#    prod_code  prod_limit  new_balance  highest_balance
# ...

# %%
df2.corr()
# Out:
#                     label        id     fea_1     fea_2     fea_3     fea_4  \
# label            1.000000 -0.008218  0.032233 -0.055798  0.049188 -0.152145
# id              -0.008218  1.000000 -0.075103  0.041802 -0.026359 -0.024619
# fea_1            0.032233 -0.075103  1.000000 -0.001196  0.002138 -0.135093
# fea_2           -0.055798  0.041802 -0.001196  1.000000 -0.229749  0.264244
# fea_3            0.049188 -0.026359  0.002138 -0.229749  1.000000 -0.093287
# fea_4           -0.152145 -0.024619 -0.135093  0.264244 -0.093287  1.000000
# fea_5            0.022042 -0.045054 -0.022554  0.012146 -0.018539  0.051830
# fea_6            0.054692 -0.013868  0.319891 -0.015965  0.159807 -0.188123
# fea_7           -0.012302 -0.020003  0.013758  0.014553  0.275816 -0.072641
# fea_8           -0.017589  0.028206  0.094130  0.015084  0.051697 -0.080010
# fea_9           -0.018590  0.001848 -0.080666  0.125084  0.115322  0.114225
# ...

# %%
df2=df2.drop(columns='fea_2')
df2=df2.drop(columns='fea_7')
df2=df2.drop(columns='fea_8')
df2.head()
# Out:
#    label        id  fea_1  fea_3     fea_4  fea_5  fea_6  fea_9  fea_10  \
# 0      1  54982665      5      3   77000.0      2     15      5  151300
# 1      1  54982665      5      3   77000.0      2     15      5  151300
# 2      1  54982665      5      3   77000.0      2     15      5  151300
# 3      1  54982665      5      3   77000.0      2     15      5  151300
# 4      0  59004779      4      1  113000.0      2      8      3  341759
#
#        fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0  244.948974       0       0       0        0           9         10
# 1  244.948974       0       0       0        0          18         10
# 2  244.948974       0       0       0        0           1          5
# 3  244.948974       0       2      26    11906           6         10
# 4  207.173840       0       0       0        0           4          6
#
#    prod_limit  new_balance  highest_balance
# 0     60500.0       6657.6          18934.0
# ...

# %%
x=df2[['id','fea_1','fea_3','fea_5','fea_9','fea_10','fea_11','new_balance','highest_balance','OVD_t2']]
y=df2['label']

# %%
x.isnull().fillna(0)
# Out:
#          id  fea_1  fea_3  fea_5  fea_9  fea_10  fea_11  new_balance  \
# 0     False  False  False  False  False   False   False        False
# 1     False  False  False  False  False   False   False        False
# 2     False  False  False  False  False   False   False        False
# 3     False  False  False  False  False   False   False        False
# 4     False  False  False  False  False   False   False        False
# ...     ...    ...    ...    ...    ...     ...     ...          ...
# 8245  False  False  False  False  False   False   False        False
# 8246  False  False  False  False  False   False   False        False
# 8247  False  False  False  False  False   False   False        False
# 8248  False  False  False  False  False   False   False        False
# 8249  False  False  False  False  False   False   False        False
#
#       highest_balance  OVD_t2
# 0               False   False
# 1               False   False
# 2               False   False
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 6600

# %%
len(x_test)
# Out:
# 1650

# %%
np.isnan(x_test)
np.where(np.isnan(x_test))
np.nan_to_num(x_test)

from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
clf.score(x_test,y_test)
# Out:
# 0.9133333333333333

# %%
clf.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn import svm

# %%
df2=df2['highest_balance'].fillna(df2['highest_balance'].mean(),inplace=True)

# %%
x=x.isnull().fillna(0)
x.isnull().sum()
# Out:
# id                 0
# fea_1              0
# fea_3              0
# fea_5              0
# fea_9              0
# fea_10             0
# fea_11             0
# new_balance        0
# highest_balance    0
# OVD_t2             0
# dtype: int64

# %%
len(x)
# Out:
# 8250

# %%
x_train['highest_balance'].fillna(x_train['highest_balance'].mean(),inplace=True)
x_train.isnull().sum()
x_test['highest_balance'].fillna(x_test['highest_balance'].mean(),inplace=True)
x_test.isnull().sum()
# Out:
# id                 0
# fea_1              0
# fea_3              0
# fea_5              0
# fea_9              0
# fea_10             0
# fea_11             0
# new_balance        0
# highest_balance    0
# OVD_t2             0
# dtype: int64

# %%
clf1 = svm.SVC()
clf1.fit(x_train, y_train)
# Out:
# SVC()

# %%
clf1.score(x_test,y_test)
# Out:
# 0.8242424242424242

# %%
clf2=LogisticRegression()

# %%
clf2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf2.score(x_test,y_test)
# Out:
# 0.8242424242424242

# %%
from sklearn.decomposition import PCA
pca=PCA(0.95)
x_pca=pca.fit_transform(x)

# %%
pca.n_components_
# Out:
# 1

# %%
import pickle

# %%
pickle.dump(clf,open('clf.pkl','wb'))

# %%
pickled_model=pickle.load(open('clf.pkl','rb'))
